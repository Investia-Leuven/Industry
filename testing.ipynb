# %%
from yfinance import Sector

sector = Sector("technology")
print(sector.industries)       # Industries within Technology
print(sector.top_companies)    # Top companies in the Technology sector
# Out:
#                                                                   name  \
# key
# semiconductors                                          Semiconductors
# software-infrastructure                      Software - Infrastructure
# consumer-electronics                              Consumer Electronics
# software-application                            Software - Application
# information-technology-services        Information Technology Services
# semiconductor-equipment-materials  Semiconductor Equipment & Materials
# communication-equipment                        Communication Equipment
# computer-hardware                                    Computer Hardware
# electronic-components                            Electronic Components
# scientific-technical-instruments    Scientific & Technical Instruments
# solar                                                            Solar
# electronics-computer-distribution  Electronics & Computer Distribution
#
#                                         symbol  market weight
# key
# semiconductors                     ^YH31130020       0.319015
# software-infrastructure            ^YH31110030       0.282103
# consumer-electronics               ^YH31120030       0.146258
# software-application               ^YH31110020       0.119514
# information-technology-services    ^YH31110010       0.040094
# semiconductor-equipment-materials  ^YH31130010       0.022146
# communication-equipment            ^YH31120010       0.021996
# computer-hardware                  ^YH31120020       0.020124
# electronic-components              ^YH31120040       0.016126
# scientific-technical-instruments   ^YH31120060       0.009243
# solar                              ^YH31130030       0.001958
# electronics-computer-distribution  ^YH31120050       0.001423
#                                                 name      rating  \
# symbol
# NVDA                              NVIDIA Corporation  Strong Buy
# MSFT                           Microsoft Corporation  Strong Buy
# AAPL                                      Apple Inc.         Buy
# AVGO                                   Broadcom Inc.  Strong Buy
# ORCL                              Oracle Corporation         Buy
# PLTR                      Palantir Technologies Inc.        Hold
# CSCO                             Cisco Systems, Inc.         Buy
# IBM      International Business Machines Corporation         Buy
# AMD                     Advanced Micro Devices, Inc.         Buy
# CRM                                 Salesforce, Inc.         Buy
# INTU                                     Intuit Inc.         Buy
# NOW                                 ServiceNow, Inc.  Strong Buy
# TXN                   Texas Instruments Incorporated        Hold
# UBER                         Uber Technologies, Inc.         Buy
# ACN                                    Accenture plc         Buy
# QCOM                           QUALCOMM Incorporated         Buy
# ADBE                                      Adobe Inc.         Buy
# AMAT                         Applied Materials, Inc.         Buy
# ANET                             Arista Networks Inc         Buy
# LRCX                        Lam Research Corporation         Buy
# MU                           Micron Technology, Inc.         Buy
# APH                             Amphenol Corporation         Buy
# KLAC                                 KLA Corporation         Buy
# ADP                  Automatic Data Processing, Inc.        Hold
# ADI                             Analog Devices, Inc.         Buy
# CRWD                      CrowdStrike Holdings, Inc.         Buy
# INTC                               Intel Corporation        Hold
# MSTR                           Strategy Incorporated         Buy
# FI                                      Fiserv, Inc.         Buy
# DELL                          Dell Technologies Inc.         Buy
# SNPS                                  Synopsys, Inc.  Strong Buy
# CDNS                    Cadence Design Systems, Inc.         Buy
# FTNT                                  Fortinet, Inc.        Hold
# SNOW                                  Snowflake Inc.         Buy
# MSI                         Motorola Solutions, Inc.         Buy
# NET                                 Cloudflare, Inc.         Buy
# MRVL                        Marvell Technology, Inc.         Buy
# PANW                        Palo Alto Networks, Inc.         Buy
# ADSK                                  Autodesk, Inc.         Buy
# WDAY                                   Workday, Inc.         Buy
# ROP                         Roper Technologies, Inc.         Buy
# NXPI                         NXP Semiconductors N.V.         Buy
# TEL                              TE Connectivity plc         Buy
# PAYX                                   Paychex, Inc.        Hold
# TEAM                           Atlassian Corporation         Buy
# DDOG                                   Datadog, Inc.         Buy
# GLW                             Corning Incorporated         Buy
# ZS                                     Zscaler, Inc.         Buy
# GRMN                                     Garmin Ltd.        Hold
# FIS     Fidelity National Information Services, Inc.         Buy
#
#         market weight
# symbol
# NVDA         0.200601
# MSFT         0.180165
# AAPL         0.151658
# AVGO         0.062873
# ORCL         0.032314
# PLTR         0.016615
# CSCO         0.012876
# IBM          0.012558
# AMD          0.012104
# CRM          0.011930
# INTU         0.010009
# NOW          0.009443
# TXN          0.009388
# UBER         0.009063
# ACN          0.008385
# QCOM         0.008171
# ADBE         0.007650
# AMAT         0.007459
# ANET         0.006690
# LRCX         0.006153
# MU           0.006054
# APH          0.005919
# KLAC         0.005917
# ADP          0.005842
# ADI          0.005703
# CRWD         0.005570
# INTC         0.004733
# MSTR         0.004710
# FI           0.004480
# DELL         0.004369
# SNPS         0.004282
# CDNS         0.004112
# FTNT         0.003839
# SNOW         0.003401
# MSI          0.003338
# NET          0.003218
# MRVL         0.003069
# PANW         0.003052
# ADSK         0.003041
# WDAY         0.002945
# ROP          0.002775
# NXPI         0.002728
# TEL          0.002544
# PAYX         0.002453
# TEAM         0.002411
# DDOG         0.002341
# GLW          0.002197
# ZS           0.002105
# GRMN         0.002079
# FIS          0.002055

# %%
from yfinance import Industry

# Choose an industry key — from the official list
industry = Industry("waste-management")

# Get a list of top companies
df_top = industry.top_companies

# Growth leaders
df_growth = industry.top_growth_companies

# Strong performers
df_perf = industry.top_performing_companies

df_top
# Out:
#                                           name      rating  market weight
# symbol
# WM                      Waste Management, Inc.         Buy       0.352462
# RSG                    Republic Services, Inc.         Buy       0.290941
# WCN                    Waste Connections, Inc.         Buy       0.182040
# GFL                     GFL Environmental Inc.         Buy       0.072124
# CLH                        Clean Harbors, Inc.         Buy       0.047423
# CWST               Casella Waste Systems, Inc.         Buy       0.026401
# SRCL                          Stericycle, Inc.        Hold       0.022228
# MEG         Montrose Environmental Group, Inc.         Buy       0.002907
# NVRI                        Enviri Corporation         Buy       0.002777
# PESI    Perma-Fix Environmental Services, Inc.  Strong Buy       0.000697

# %%
from yfinance import Industry

industry_key = "farm-heavy-construction-machinery"

try:
    ind = Industry(industry_key)
    top_df = ind.top_companies
except Exception as e:
    print(f"Error: {e}")

top_df
# Out:
#                                  name      rating  market weight
# symbol
# CAT                  Caterpillar Inc.         Buy       0.461154
# DE                    Deere & Company         Buy       0.315726
# PCAR                       PACCAR Inc        Hold       0.113399
# CNH               CNH Industrial N.V.         Buy       0.037372
# OSK               Oshkosh Corporation         Buy       0.018533
# AGCO                 AGCO Corporation        Hold       0.018444
# TEX                 Terex Corporation        Hold       0.007613
# ALG                  Alamo Group Inc.         Buy       0.006046
# REVG                  REV Group, Inc.         Buy       0.005562
# LNN               Lindsay Corporation         Buy       0.003438
# BLBD            Blue Bird Corporation         Buy       0.003185
# ASTE           Astec Industries, Inc.         Buy       0.001999
# HY                  Hyster-Yale, Inc.         Buy       0.001652
# TWI         Titan International, Inc.  Strong Buy       0.001318
# CMCO    Columbus McKinnon Corporation         Buy       0.001011
# SHYF            The Shyft Group, Inc.         Buy       0.000999
# MTW       The Manitowoc Company, Inc.        Hold       0.000998
# WNC       Wabash National Corporation         Buy       0.000970
# GENC          Gencor Industries, Inc.  Strong Buy       0.000468
# AGFY               Agrify Corporation         Buy       0.000099
# CEAD              CEA Industries Inc.        None       0.000016

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.65-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/vincecoppens/Library/Python/3.12/lib/python/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (2024.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py312-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.2.tar.gz (949 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.2/949.2 kB 9.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.12.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.2)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance)
#   Downloading cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi>=2024.2.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vincecoppens/Library/Python/3.12/lib/python/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.3.0)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: six>=1.5 in /Users/vincecoppens/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Downloading yfinance-0.2.65-py2.py3-none-any.whl (119 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading curl_cffi-0.12.0-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 10.9 MB/s eta 0:00:00a 0:00:01
# Downloading frozendict-2.4.6-py312-none-any.whl (16 kB)
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl (425 kB)
# Downloading websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Downloading cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl (178 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.18.2-cp312-cp312-macosx_10_13_universal2.whl size=438005 sha256=50e044c9230a9fd166325e41aa816c829ac547e559c0ff661ff69e38b55e1d17
#   Stored in directory: /Users/vincecoppens/Library/Caches/pip/wheels/d1/df/a9/0202b051c65b11c992dd6db9f2babdd2c44ec7d35d511be5d3
# Successfully built peewee
# Installing collected packages: peewee, multitasking, websockets, soupsieve, pycparser, protobuf, frozendict, cffi, beautifulsoup4, curl_cffi, yfinance
# Successfully installed beautifulsoup4-4.13.4 cffi-1.17.1 curl_cffi-0.12.0 frozendict-2.4.6 multitasking-0.0.11 peewee-3.18.2 protobuf-6.31.1 pycparser-2.22 soupsieve-2.7 websockets-15.0.1 yfinance-0.2.65
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
